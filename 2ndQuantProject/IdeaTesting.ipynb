# %% [markdown]
# # Signal Generation using Eigenvectors and Eigenvalues from COV MATRIX of S&P500
#
# ### Attempt to see if I can model the covariance matrix of all stocks in the S&P500 and get their eigenvalues and eigenvectors
# ### After getting the direction of the eigenvectors and based on a magnitude of the eigenvalue, we can produce single buy or sell signal for S&P500 intra-day.
# ### Use the signal to buy CALL or PUT option on $SPY to get returns.
