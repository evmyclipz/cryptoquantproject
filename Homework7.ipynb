# %% [markdown]
# # Fundamental Stock Data
# In this homework we will guide you through how to download free historical fundamentals for stocks. This data can be used to construct value and other fundamental strategies. There will be no "solution" for this homework as it is more of a guide.
#
# ### Packages
# We will be using the <a href='https://pypi.org/project/simfin/' target="_blank" >simfin</a> and  <a href='https://pypi.org/project/yfinance/' target="_blank" >yfinance</a> packages. Install them using "pip install simfin" and "pip install yfinance" if you haven't already and import them as below.

# %%
pip install simfin
# Out:
# Requirement already satisfied: simfin in c:\users\mroha\appdata\local\programs\python\python313\lib\site-packages (1.0.1)
# Requirement already satisfied: pandas in c:\users\mroha\appdata\local\programs\python\python313\lib\site-packages (from simfin) (2.3.1)
# Requirement already satisfied: numpy in c:\users\mroha\appdata\local\programs\python\python313\lib\site-packages (from simfin) (2.3.1)
# Requirement already satisfied: requests in c:\users\mroha\appdata\local\programs\python\python313\lib\site-packages (from simfin) (2.32.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mroha\appdata\roaming\python\python313\site-packages (from pandas->simfin) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mroha\appdata\local\programs\python\python313\lib\site-packages (from pandas->simfin) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mroha\appdata\local\programs\python\python313\lib\site-packages (from pandas->simfin) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\mroha\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas->simfin) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\mroha\appdata\local\programs\python\python313\lib\site-packages (from requests->simfin) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mroha\appdata\local\programs\python\python313\lib\site-packages (from requests->simfin) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mroha\appdata\local\programs\python\python313\lib\site-packages (from requests->simfin) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mroha\appdata\local\programs\python\python313\lib\site-packages (from requests->simfin) (2025.7.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf 
import simfin as sf

# %% [markdown]
# ### Get Your SimFin API Key
#
# First you must obtain an API key. Make an account at https://simfin.com. Confirm your account via email and then head to https://simfin.com/data/api to obtain your api key.

# %%
# set your api key here
api_key = '2a2c99fb-4974-4998-b958-935fb3edb4ec'
sf.config.set_api_key(api_key=api_key)

# %% [markdown]
# ### Set Your SimFin Data Directory
#
# Simfin requires you to set a data directory where simfin data will be downloaded. Downloaded data is used for faster retrieval in the future. The default location is a folder named simfin_data in the home directory.

# %%
# set simfin_data
sf.set_data_dir(r'C:\Users\mroha\Documents\wallStreetQuantNotes\Finances\simfin_data')

# %% [markdown]
# ### Download historical financial data from simfin.
# The three financial statements containing fundamental data are the quarterly income, balance sheet and cash flows statements. Data from these statements can be loaded for all us tickers from simfin as below.

# %%
income = sf.load_income(variant='quarterly', market='us')

balance_sheet = sf.load_balance(variant='quarterly', market='us')

cash_flow = sf.load_cashflow(variant='quarterly', market='us')
# Out:
# Dataset "us-income-quarterly" on disk (0 days old).
# - Loading from disk ... Done!
# Dataset "us-balance-quarterly" on disk (0 days old).
# - Loading from disk ...
# c:\Users\mroha\AppData\Local\Programs\Python\Python313\Lib\site-packages\simfin\load.py:154: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df = pd.read_csv(path, sep=';', header=0,
# c:\Users\mroha\AppData\Local\Programs\Python\Python313\Lib\site-packages\simfin\load.py:154: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df = pd.read_csv(path, sep=';', header=0,
# Done!
# Dataset "us-cashflow-quarterly" on disk (0 days old).
# - Loading from disk ... Done!
# c:\Users\mroha\AppData\Local\Programs\Python\Python313\Lib\site-packages\simfin\load.py:154: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df = pd.read_csv(path, sep=';', header=0,

# %% [markdown]
# Below we observe the shape of the data.
#
# All of the results are multi-index dataframes where the row is (ticker,date) and the column is a financial statement item.
#
# One of the important columns for backtesting is the Publish Date. This is the date the information was available to the public.
#
# For backtesting, we can assume the simfin data is available 1 business day after the Publish Date, since companies sometimes publish after market close or because we may not always be able to get the data immediately on publication for trading, depending on which data vendor you use.
#
# Because there are restatements to financial statements, even this will not be a fully "point-in-time" backtest where we only use information available at the time. It should be a reasonable approximation in many cases, however.

# %%
cash_flow.head()
# Out:
#                     SimFinId Currency  Fiscal Year Fiscal Period Publish Date  \
# Ticker Report Date
# A      2019-10-31      45846      USD         2019            Q4   2019-12-19
#        2020-01-31      45846      USD         2020            Q1   2020-03-03
#        2020-04-30      45846      USD         2020            Q2   2020-06-01
#        2020-07-31      45846      USD         2020            Q3   2020-09-01
#        2020-10-31      45846      USD         2020            Q4   2020-12-18
#
#                    Restated Date  Shares (Basic)  Shares (Diluted)  \
# Ticker Report Date
# A      2019-10-31     2019-08-30     309000000.0       313000000.0
#        2020-01-31     2021-03-02     310000000.0       313000000.0
#        2020-04-30     2021-03-02     309000000.0       312000000.0
#        2020-07-31     2021-06-01     309000000.0       312000000.0
#        2020-10-31     2021-09-01     308000000.0       311000000.0
#
#                     Net Income/Starting Line  Depreciation & Amortization  \
# Ticker Report Date
# A      2019-10-31                194000000.0                   76000000.0
#        2020-01-31                197000000.0                   79000000.0
#        2020-04-30                101000000.0                   76000000.0
#        2020-07-31                199000000.0                   77000000.0
#        2020-10-31                222000000.0                   76000000.0
#
#                     ...  Net Cash from Operating Activities  \
# Ticker Report Date  ...
# A      2019-10-31   ...                           314000000
#        2020-01-31   ...                           -59000000
#        2020-04-30   ...                           313000000
#        2020-07-31   ...                           290000000
#        2020-10-31   ...                           377000000
#
#                     Change in Fixed Assets & Intangibles  \
# Ticker Report Date
# A      2019-10-31                            -30000000.0
#        2020-01-31                            -34000000.0
#        2020-04-30                            -33000000.0
#        2020-07-31                            -24000000.0
#        2020-10-31                            -27000000.0
#
#                     Net Change in Long Term Investment  \
# Ticker Report Date
# A      2019-10-31                                  NaN
#        2020-01-31                                  NaN
#        2020-04-30                                  NaN
#        2020-07-31                                  NaN
#        2020-10-31                                  NaN
#
#                     Net Cash from Acquisitions & Divestitures  \
# Ticker Report Date
# A      2019-10-31                               -1.160000e+09
#        2020-01-31                                         NaN
#        2020-04-30                                         NaN
#        2020-07-31                                         NaN
#        2020-10-31                                         NaN
#
#                     Net Cash from Investing Activities  Dividends Paid  \
# Ticker Report Date
# A      2019-10-31                        -1.193000e+09     -51000000.0
#        2020-01-31                        -3.500000e+07     -56000000.0
#        2020-04-30                        -5.300000e+07     -55000000.0
#        2020-07-31                        -3.200000e+07     -56000000.0
#        2020-10-31                        -2.700000e+07     -55000000.0
#
#                     Cash from (Repayment of) Debt  \
# Ticker Report Date
# A      2019-10-31                     600000000.0
#        2020-01-31                      56000000.0
#        2020-04-30                      25000000.0
#        2020-07-31                    -161000000.0
#        2020-10-31                      35000000.0
#
#                     Cash from (Repurchase of) Equity  \
# Ticker Report Date
# A      2019-10-31                        -47000000.0
#        2020-01-31                        -28000000.0
#        2020-04-30                       -126000000.0
#        2020-07-31                         -9000000.0
#        2020-10-31                       -246000000.0
#
#                     Net Cash from Financing Activities  Net Change in Cash
# Ticker Report Date
# A      2019-10-31                          497000000.0          -383000000
#        2020-01-31                          -61000000.0          -156000000
#        2020-04-30                         -156000000.0            97000000
#        2020-07-31                         -231000000.0            35000000
#        2020-10-31                         -269000000.0            83000000
#
# [5 rows x 26 columns]

# %% [markdown]
# Let's observe which columns are available to us below from each financial statement.

# %%
# observe available income columns
income.columns
# Out:
# Index(['SimFinId', 'Currency', 'Fiscal Year', 'Fiscal Period', 'Publish Date',
#        'Restated Date', 'Shares (Basic)', 'Shares (Diluted)', 'Revenue',
#        'Cost of Revenue', 'Gross Profit', 'Operating Expenses',
#        'Selling, General & Administrative', 'Research & Development',
#        'Depreciation & Amortization', 'Operating Income (Loss)',
#        'Non-Operating Income (Loss)', 'Interest Expense, Net',
#        'Pretax Income (Loss), Adj.', 'Abnormal Gains (Losses)',
#        'Pretax Income (Loss)', 'Income Tax (Expense) Benefit, Net',
#        'Income (Loss) from Continuing Operations',
#        'Net Extraordinary Gains (Losses)', 'Net Income',
#        'Net Income (Common)'],
#       dtype='object')

# %%
# observe available balance_sheet columns
balance_sheet.columns
# Out:
# Index(['SimFinId', 'Currency', 'Fiscal Year', 'Fiscal Period', 'Publish Date',
#        'Restated Date', 'Shares (Basic)', 'Shares (Diluted)',
#        'Cash, Cash Equivalents & Short Term Investments',
#        'Accounts & Notes Receivable', 'Inventories', 'Total Current Assets',
#        'Property, Plant & Equipment, Net',
#        'Long Term Investments & Receivables', 'Other Long Term Assets',
#        'Total Noncurrent Assets', 'Total Assets', 'Payables & Accruals',
#        'Short Term Debt', 'Total Current Liabilities', 'Long Term Debt',
#        'Total Noncurrent Liabilities', 'Total Liabilities',
#        'Share Capital & Additional Paid-In Capital', 'Treasury Stock',
#        'Retained Earnings', 'Total Equity', 'Total Liabilities & Equity'],
#       dtype='object')

# %%
# observe available cash_flow columns
cash_flow.columns
# Out:
# Index(['SimFinId', 'Currency', 'Fiscal Year', 'Fiscal Period', 'Publish Date',
#        'Restated Date', 'Shares (Basic)', 'Shares (Diluted)',
#        'Net Income/Starting Line', 'Depreciation & Amortization',
#        'Non-Cash Items', 'Change in Working Capital',
#        'Change in Accounts Receivable', 'Change in Inventories',
#        'Change in Accounts Payable', 'Change in Other',
#        'Net Cash from Operating Activities',
#        'Change in Fixed Assets & Intangibles',
#        'Net Change in Long Term Investment',
#        'Net Cash from Acquisitions & Divestitures',
#        'Net Cash from Investing Activities', 'Dividends Paid',
#        'Cash from (Repayment of) Debt', 'Cash from (Repurchase of) Equity',
#        'Net Cash from Financing Activities', 'Net Change in Cash'],
#       dtype='object')

# %% [markdown]
# Below we observe the number of tickers available for each statement and the start and end dates.

# %%
def describe_data(data, data_name):
    size = len(set(data.index.get_level_values(0)))
    start_dt = data.index.get_level_values(1).min().strftime('%Y%m%d')
    end_dt = data.index.get_level_values(1).max().strftime('%Y%m%d')
    print (f'{data_name}: {size} tickers. Date range: {start_dt} to {end_dt}')

describe_data(income ,'Income Data')
describe_data(balance_sheet ,'Balance Sheet Data')
describe_data(cash_flow ,'Cash Flow Data')
# Out:
# Income Data: 3646 tickers. Date range: 20190930 to 20240731
# Balance Sheet Data: 3646 tickers. Date range: 20190930 to 20240731
# Cash Flow Data: 3646 tickers. Date range: 20190930 to 20240731

# %% [markdown]
# ### Yahoo Finance Data
# If you notice above, the simfin data ends a year ago. They only have 1 year lagged data. To get the most recent financial statement information, you can use yahoo finance.
#
# First you must obtain a yfinance.Ticker object for your desired ticker.

# %%
yf_ticker = yf.Ticker('CAT')

# %% [markdown]
# Download information from the 3 financial statements as below.

# %%
# Get the quarterly cash flow statements from yfinance

income_yf = yf_ticker.quarterly_financials

cash_flow_yf = yf_ticker.quarterly_cashflow

balance_sheet = yf_ticker.quarterly_balance_sheet

# %%
income_yf
# Out:
#                                                       2025-06-30  \
# Tax Effect Of Unusual Items                        -3.667850e+06
# Tax Rate For Calcs                                  2.292410e-01
# Normalized EBITDA                                   3.514000e+09
# Total Unusual Items                                -1.600000e+07
# Total Unusual Items Excluding Goodwill             -1.600000e+07
# Net Income From Continuing Operation Net Minori...  2.179000e+09
# Reconciled Depreciation                             5.540000e+08
# Reconciled Cost Of Revenue                          1.114300e+10
# EBITDA                                              3.498000e+09
# EBIT                                                2.944000e+09
# Net Interest Income                                -1.260000e+08
# Interest Expense                                    1.260000e+08
# Interest Income                                              NaN
# Normalized Income                                   2.191332e+09
# Net Income From Continuing And Discontinued Ope...  2.179000e+09
# Total Expenses                                      1.370900e+10
# Total Operating Income As Reported                  2.860000e+09
# Diluted Average Shares                              4.715000e+08
# Basic Average Shares                                4.697000e+08
# Diluted EPS                                         4.620000e+00
# Basic EPS                                           4.640000e+00
# Diluted NI Availto Com Stockholders                 2.179000e+09
# Net Income Common Stockholders                      2.179000e+09
# Net Income                                          2.179000e+09
# Minority Interests                                  0.000000e+00
# Net Income Including Noncontrolling Interests       2.179000e+09
# Net Income Continuous Operations                    2.179000e+09
# Earnings From Equity Interest Net Of Tax            7.000000e+06
# Tax Provision                                       6.460000e+08
# Pretax Income                                       2.818000e+09
# Other Income Expense                                8.400000e+07
# Other Non Operating Income Expenses                 1.000000e+08
# Gain On Sale Of Security                           -1.600000e+07
# Net Non Operating Interest Income Expense          -1.260000e+08
# Interest Expense Non Operating                      1.260000e+08
# Interest Income Non Operating                                NaN
# Operating Income                                    2.860000e+09
# Operating Expense                                   2.566000e+09
# Other Operating Expenses                            3.210000e+08
# Research And Development                            5.510000e+08
# Selling General And Administration                  1.694000e+09
# Gross Profit                                        5.426000e+09
# Cost Of Revenue                                     1.114300e+10
# Total Revenue                                       1.656900e+10
# Operating Revenue                                   1.656900e+10
#
#                                                       2025-03-31  \
# Tax Effect Of Unusual Items                         1.873200e+07
# Tax Rate For Calcs                                  2.230000e-01
# Normalized EBITDA                                   3.142000e+09
# Total Unusual Items                                 8.400000e+07
# Total Unusual Items Excluding Goodwill              8.400000e+07
# Net Income From Continuing Operation Net Minori...  2.003000e+09
# Reconciled Depreciation                             5.400000e+08
# Reconciled Cost Of Revenue                          9.291000e+09
# EBITDA                                              3.226000e+09
# EBIT                                                2.686000e+09
# Net Interest Income                                -1.160000e+08
# Interest Expense                                    1.160000e+08
# Interest Income                                              NaN
# Normalized Income                                   1.937732e+09
# Net Income From Continuing And Discontinued Ope...  2.003000e+09
# Total Expenses                                      1.167000e+10
# Total Operating Income As Reported                  2.579000e+09
# Diluted Average Shares                              4.771000e+08
# Basic Average Shares                                4.749000e+08
# Diluted EPS                                         4.200000e+00
# Basic EPS                                           4.220000e+00
# Diluted NI Availto Com Stockholders                 2.003000e+09
# Net Income Common Stockholders                      2.003000e+09
# Net Income                                          2.003000e+09
# Minority Interests                                  0.000000e+00
# Net Income Including Noncontrolling Interests       2.003000e+09
# Net Income Continuous Operations                    2.003000e+09
# Earnings From Equity Interest Net Of Tax            7.000000e+06
# Tax Provision                                       5.740000e+08
# Pretax Income                                       2.570000e+09
# Other Income Expense                                1.070000e+08
# Other Non Operating Income Expenses                 2.300000e+07
# Gain On Sale Of Security                            8.400000e+07
# Net Non Operating Interest Income Expense          -1.160000e+08
# Interest Expense Non Operating                      1.160000e+08
# Interest Income Non Operating                                NaN
# Operating Income                                    2.579000e+09
# Operating Expense                                   2.379000e+09
# Other Operating Expenses                            3.060000e+08
# Research And Development                            4.800000e+08
# Selling General And Administration                  1.593000e+09
# Gross Profit                                        4.958000e+09
# Cost Of Revenue                                     9.291000e+09
# Total Revenue                                       1.424900e+10
# Operating Revenue                                   1.424900e+10
#
#                                                       2024-12-31  \
# Tax Effect Of Unusual Items                         3.769103e+07
# Tax Rate For Calcs                                  1.427690e-01
# Normalized EBITDA                                   3.641000e+09
# Total Unusual Items                                 2.640000e+08
# Total Unusual Items Excluding Goodwill              2.640000e+08
# Net Income From Continuing Operation Net Minori...  2.791000e+09
# Reconciled Depreciation                             5.550000e+08
# Reconciled Cost Of Revenue                          1.065900e+10
# EBITDA                                              3.905000e+09
# EBIT                                                3.350000e+09
# Net Interest Income                                -1.070000e+08
# Interest Expense                                    1.070000e+08
# Interest Income                                     1.200000e+08
# Normalized Income                                   2.564691e+09
# Net Income From Continuing And Discontinued Ope...  2.791000e+09
# Total Expenses                                      1.329100e+10
# Total Operating Income As Reported                  2.924000e+09
# Diluted Average Shares                              4.826000e+08
# Basic Average Shares                                4.800000e+08
# Diluted EPS                                         5.780000e+00
# Basic EPS                                           5.810000e+00
# Diluted NI Availto Com Stockholders                 2.791000e+09
# Net Income Common Stockholders                      2.791000e+09
# Net Income                                          2.791000e+09
# Minority Interests                                  1.000000e+06
# Net Income Including Noncontrolling Interests       2.790000e+09
# Net Income Continuous Operations                    2.790000e+09
# Earnings From Equity Interest Net Of Tax            1.000000e+07
# Tax Provision                                       4.630000e+08
# Pretax Income                                       3.243000e+09
# Other Income Expense                                4.260000e+08
# Other Non Operating Income Expenses                 1.620000e+08
# Gain On Sale Of Security                            2.640000e+08
# Net Non Operating Interest Income Expense          -1.070000e+08
# Interest Expense Non Operating                      1.070000e+08
# Interest Income Non Operating                       1.200000e+08
# Operating Income                                    2.924000e+09
# Operating Expense                                   2.632000e+09
# Other Operating Expenses                            3.440000e+08
# Research And Development                            5.190000e+08
# Selling General And Administration                  1.769000e+09
# Gross Profit                                        5.556000e+09
# Cost Of Revenue                                     1.065900e+10
# Total Revenue                                       1.621500e+10
# Operating Revenue                                   1.621500e+10
#
#                                                       2024-09-30  \
# Tax Effect Of Unusual Items                         6.210000e+05
# Tax Rate For Calcs                                  2.070000e-01
# Normalized EBITDA                                   3.763000e+09
# Total Unusual Items                                 3.000000e+06
# Total Unusual Items Excluding Goodwill              3.000000e+06
# Net Income From Continuing Operation Net Minori...  2.464000e+09
# Reconciled Depreciation                             5.430000e+08
# Reconciled Cost Of Revenue                          1.040200e+10
# EBITDA                                              3.766000e+09
# EBIT                                                3.223000e+09
# Net Interest Income                                -1.250000e+08
# Interest Expense                                    1.250000e+08
# Interest Income                                     1.080000e+08
# Normalized Income                                   2.461621e+09
# Net Income From Continuing And Discontinued Ope...  2.464000e+09
# Total Expenses                                      1.295900e+10
# Total Operating Income As Reported                  3.147000e+09
# Diluted Average Shares                              4.867000e+08
# Basic Average Shares                                4.842000e+08
# Diluted EPS                                         5.060000e+00
# Basic EPS                                           5.090000e+00
# Diluted NI Availto Com Stockholders                 2.464000e+09
# Net Income Common Stockholders                      2.464000e+09
# Net Income                                          2.464000e+09
# Minority Interests                                  1.000000e+06
# Net Income Including Noncontrolling Interests       2.463000e+09
# Net Income Continuous Operations                    2.463000e+09
# Earnings From Equity Interest Net Of Tax            7.000000e+06
# Tax Provision                                       6.420000e+08
# Pretax Income                                       3.098000e+09
# Other Income Expense                                7.600000e+07
# Other Non Operating Income Expenses                 7.300000e+07
# Gain On Sale Of Security                            3.000000e+06
# Net Non Operating Interest Income Expense          -1.250000e+08
# Interest Expense Non Operating                      1.250000e+08
# Interest Income Non Operating                       1.080000e+08
# Operating Income                                    3.147000e+09
# Operating Expense                                   2.557000e+09
# Other Operating Expenses                            3.550000e+08
# Research And Development                            5.330000e+08
# Selling General And Administration                  1.669000e+09
# Gross Profit                                        5.704000e+09
# Cost Of Revenue                                     1.040200e+10
# Total Revenue                                       1.610600e+10
# Operating Revenue                                   1.610600e+10
#
#                                                       2024-06-30   2024-03-31  \
# Tax Effect Of Unusual Items                         3.105143e+07          NaN
# Tax Rate For Calcs                                  2.388570e-01          NaN
# Normalized EBITDA                                   4.038000e+09          NaN
# Total Unusual Items                                 1.300000e+08          NaN
# Total Unusual Items Excluding Goodwill              1.300000e+08          NaN
# Net Income From Continuing Operation Net Minori...  2.681000e+09          NaN
# Reconciled Depreciation                             5.310000e+08          NaN
# Reconciled Cost Of Revenue                          1.046400e+10          NaN
# EBITDA                                              4.168000e+09          NaN
# EBIT                                                3.637000e+09          NaN
# Net Interest Income                                -1.370000e+08          NaN
# Interest Expense                                    1.370000e+08          NaN
# Interest Income                                     1.180000e+08  136000000.0
# Normalized Income                                   2.582051e+09          NaN
# Net Income From Continuing And Discontinued Ope...  2.681000e+09          NaN
# Total Expenses                                      1.320700e+10          NaN
# Total Operating Income As Reported                  3.482000e+09          NaN
# Diluted Average Shares                              4.895000e+08          NaN
# Basic Average Shares                                4.872000e+08          NaN
# Diluted EPS                                         5.480000e+00          NaN
# Basic EPS                                           5.500000e+00          NaN
# Diluted NI Availto Com Stockholders                 2.681000e+09          NaN
# Net Income Common Stockholders                      2.681000e+09          NaN
# Net Income                                          2.681000e+09          NaN
# Minority Interests                                  0.000000e+00          NaN
# Net Income Including Noncontrolling Interests       2.681000e+09          NaN
# Net Income Continuous Operations                    2.681000e+09          NaN
# Earnings From Equity Interest Net Of Tax            1.700000e+07          NaN
# Tax Provision                                       8.360000e+08          NaN
# Pretax Income                                       3.500000e+09          NaN
# Other Income Expense                                1.550000e+08          NaN
# Other Non Operating Income Expenses                 2.500000e+07          NaN
# Gain On Sale Of Security                            1.300000e+08          NaN
# Net Non Operating Interest Income Expense          -1.370000e+08          NaN
# Interest Expense Non Operating                      1.370000e+08          NaN
# Interest Income Non Operating                       1.180000e+08  136000000.0
# Operating Income                                    3.482000e+09          NaN
# Operating Expense                                   2.743000e+09          NaN
# Other Operating Expenses                            5.560000e+08          NaN
# Research And Development                            5.350000e+08          NaN
# Selling General And Administration                  1.652000e+09          NaN
# Gross Profit                                        6.225000e+09          NaN
# Cost Of Revenue                                     1.046400e+10          NaN
# Total Revenue                                       1.668900e+10          NaN
# Operating Revenue                                   1.668900e+10          NaN
#
#                                                      2023-12-31
# Tax Effect Of Unusual Items                                 NaN
# Tax Rate For Calcs                                          NaN
# Normalized EBITDA                                           NaN
# Total Unusual Items                                         NaN
# Total Unusual Items Excluding Goodwill                      NaN
# Net Income From Continuing Operation Net Minori...          NaN
# Reconciled Depreciation                                     NaN
# Reconciled Cost Of Revenue                                  NaN
# EBITDA                                                      NaN
# EBIT                                                        NaN
# Net Interest Income                                         NaN
# Interest Expense                                            NaN
# Interest Income                                     170000000.0
# Normalized Income                                           NaN
# Net Income From Continuing And Discontinued Ope...          NaN
# Total Expenses                                              NaN
# Total Operating Income As Reported                          NaN
# Diluted Average Shares                                      NaN
# Basic Average Shares                                        NaN
# Diluted EPS                                                 NaN
# Basic EPS                                                   NaN
# Diluted NI Availto Com Stockholders                         NaN
# Net Income Common Stockholders                              NaN
# Net Income                                                  NaN
# Minority Interests                                          NaN
# Net Income Including Noncontrolling Interests               NaN
# Net Income Continuous Operations                            NaN
# Earnings From Equity Interest Net Of Tax                    NaN
# Tax Provision                                               NaN
# Pretax Income                                               NaN
# Other Income Expense                                        NaN
# Other Non Operating Income Expenses                         NaN
# Gain On Sale Of Security                                    NaN
# Net Non Operating Interest Income Expense                   NaN
# Interest Expense Non Operating                              NaN
# Interest Income Non Operating                       170000000.0
# Operating Income                                            NaN
# Operating Expense                                           NaN
# Other Operating Expenses                                    NaN
# Research And Development                                    NaN
# Selling General And Administration                          NaN
# Gross Profit                                                NaN
# Cost Of Revenue                                             NaN
# Total Revenue                                               NaN
# Operating Revenue                                           NaN
